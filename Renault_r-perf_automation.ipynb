# %%
import pandas as pd
import numpy as np
import math

# %%
import re

# %%
xls = pd.ExcelFile(r'C:\Users\Deepika\OneDrive\Documents\Professional\Freelance\Renault\Missions\Updates_Social_Media\Arkana-Social_Media_Results_Update_27Jun.xlsx')
df_Arkana = pd.read_excel(xls, 'All Data')

# %%
xls1 = pd.ExcelFile(r'C:\Users\Deepika\OneDrive\Documents\Professional\Freelance\Renault\Missions\Updates_Social_Media\Model-Country-Platform_matrix.xlsx')
model_df = pd.read_excel(xls1, 'Model-Country')
platform_df = pd.read_excel(xls1, 'Platform-Country')

# %%
model_df
# Out:
#            Country      Models
# 0       Argentina           4L
# 1          Austria      Arkana
# 2          Austria   Kangoo PC
# 3          Austria   F1 Alpine
# 4          Austria  Kangoo Van
# 5          Belgium      Arkana
# 6          Belgium   Kangoo PC
# 7          Belgium   F1 Alpine
# 8          Belgium          4L
# 9          Belgium  Kangoo Van
# 10          Brazil          4L
# 11       Bulgaria   Kangoo Van
# 12  Czech Republic  Kangoo Van
# 13         Denmark      Arkana
# 14         Denmark          F1
# 15          France      Arkana
# 16          France          F1
# 17          France          4L
# 18          France   Kangoo PC
# 19          France  Kangoo Van
# 20         Germany      Arkana
# 21         Germany          F1
# 22         Germany          4L
# 23         Germany   Kangoo PC
# 24         Germany  Kangoo Van
# 25           India          4L
# 26           Italy      Arkana
# 27           Italy          F1
# 28           Italy          4L
# ...

# %%
model_dct = {}
for i in model_df["Country"].tolist(): 
    model_dct[i] = model_df[model_df["Country"]==i]["Models"].tolist()

# %%
model_dct = {"".join(key.split()):value for key, value in model_dct.items()}

# %%
model_dct
# Out:
# {'Argentina': ['4L'],
#  'Austria': ['Arkana', 'Kangoo PC', 'F1 Alpine', 'Kangoo Van'],
#  'Belgium': ['Arkana', 'Kangoo PC', 'F1 Alpine', '4L', 'Kangoo Van'],
#  'Brazil': ['4L'],
#  'Bulgaria': ['Kangoo Van'],
#  'CzechRepublic': ['Kangoo Van'],
#  'Denmark': ['Arkana', 'F1'],
#  'France': ['Arkana', 'F1', '4L', 'Kangoo PC', 'Kangoo Van'],
#  'Germany': ['Arkana', 'F1', '4L', 'Kangoo PC', 'Kangoo Van'],
#  'India': ['4L'],
#  'Italy': ['Arkana', 'F1', '4L', 'Kangoo PC', 'Kangoo Van'],
#  'Mexico': ['4L'],
#  'Netherlands': ['Arkana', 'F1', '4L', 'Kangoo Van'],
#  'Poland': ['Arkana', 'F1', '4L'],
#  'Romania': ['Kangoo Van'],
#  'Russia': ['4L'],
#  'Slovakia': ['Kangoo Van'],
#  'Spain': ['Arkana', 'F1', '4L', 'Kangoo PC', 'Kangoo Van'],
#  'Sweden': ['Arkana', 'F1', '4L'],
#  'Switzerland': ['Arkana', 'F1', 'Kangoo Van'],
#  'Turkey': ['4L'],
#  'UK': ['Arkana', 'F1', '4L']}

# %%
platform_dct = platform_df.set_index('Countries').T.to_dict('list')
platform_dct = {"".join(key.split()):value for key, value in platform_dct.items()}

# %%
platform_dct
# Out:
# {'Argentina': ['FB', 'IG', 'YT', 'LK', 'TW'],
#  'Austria': ['FB', 'IG', 'YT', 'LK', nan],
#  'Belgium': ['FB', 'IG', 'YT', 'LK', 'TW'],
#  'Brazil': ['FB', 'IG', 'YT', nan, 'TW'],
#  'Bulgaria': ['FB', 'IG', 'YT', nan, nan],
#  'CzechRepublic': ['FB', 'IG', 'YT', nan, nan],
#  'Denmark': ['FB', 'IG', 'YT', 'LK', nan],
#  'France': ['FB', 'IG', 'YT', 'LK', 'TW'],
#  'Germany': ['FB', 'IG', 'YT', 'LK', 'TW'],
#  'India': ['FB', 'IG', 'YT', 'LK', 'TW'],
#  'Italy': ['FB', 'IG', 'YT', nan, 'TW'],
#  'Mexico': ['FB', 'IG', 'YT', nan, 'TW'],
#  'Netherlands': ['FB', 'IG', 'YT', 'LK', 'TW'],
#  'Poland': ['FB', 'IG', 'YT', nan, nan],
#  'Romania': ['FB', 'IG', 'YT', nan, nan],
#  'Russia': ['FB', 'IG', 'YT', nan, 'TW'],
#  'Slovakia': ['FB', nan, 'YT', 'LK', 'TW'],
#  'Spain': ['FB', 'IG', 'YT', nan, 'TW'],
#  'Sweden': ['FB', 'IG', 'YT', 'LK', nan],
#  'Switzerland': ['FB', 'IG', 'YT', 'LK', nan],
#  'Turkey': ['FB', 'IG', 'YT', 'LK', 'TW'],
#  'UK': ['FB', 'IG', 'YT', 'LK', 'TW']}

# %%
for i in model_dct:
    for j in platform_dct:
        if i == j:
            print('Posted')
        else:
            print('Not Posted')
# Out:
# Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# Not Posted
# ...
